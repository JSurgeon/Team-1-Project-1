# %%
# API jupyter notebook file

# %%
# Dependencies
import requests
import json

# World bank base url
url = " http://api.worldbank.org/v2/country/?format=json"

countries = requests.get(url)
country_json = countries.json()
print(json.dumps(country_json, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "page": 1,
#         "pages": 6,
#         "per_page": "50",
#         "total": 297
#     },
#     [
#         {
#             "adminregion": {
#                 "id": "",
#                 "iso2code": "",
#                 "value": ""
#             },
#             "capitalCity": "Oranjestad",
#             "id": "ABW",
#             "incomeLevel": {
#                 "id": "HIC",
#                 "iso2code": "XD",
#                 "value": "High income"
#             },
#             "iso2Code": "AW",
#             "latitude": "12.5167",
#             "lendingType": {
#                 "id": "LNX",
#                 "iso2code": "XX",
#                 "value": "Not classified"
#             },
#             "longitude": "-70.0167",
#             "name": "Aruba",
#             "region": {
#                 "id": "LCN",
#                 "iso2code": "ZJ",
#                 "value": "Latin America & Caribbean "
#             }
#         },
#         {
# ...
